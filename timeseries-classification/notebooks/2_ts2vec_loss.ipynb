# %%
# verify if the environment (ts-classification-env) is correct and node is as expected (scotia or hermann)
import sys
print(sys.executable)

import socket
print(socket.gethostname())
# Out:
# /home/pborole/anaconda3/envs/timesfm_py311/bin/python3.11
# scotia03.inf.ed.ac.uk

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
fontsize = 14
fontsize_minor = fontsize-2

# %%
loss_df = pd.read_csv(f'./results/ts2vec/loss_ts2vec.csv') # Generated by src.modeling.train_ts2vec.py script

fig, ax = plt.subplots(1, figsize=(5,5))

b = sns.lineplot(data=loss_df, x='Epoch', y='Loss', label='train_loss', ax=ax)

b.set(ylim=(0.2, 0.5))

b.set_xlabel(b.get_xlabel(), fontsize=fontsize)
b.set_ylabel(b.get_ylabel(), fontsize=fontsize)

b.set_xticklabels(b.get_xticklabels(), fontsize=fontsize_minor)
b.set_yticklabels(b.get_yticklabels(), fontsize=fontsize_minor)

b.set_title('TS2Vec train loss', fontsize=fontsize)

b.legend_.remove()
sns.despine(top=True, right=True)
# Out:
# /tmp/ipykernel_270250/2608669220.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   b.set_xticklabels(b.get_xticklabels(), fontsize=fontsize_minor)
# /tmp/ipykernel_270250/2608669220.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   b.set_yticklabels(b.get_yticklabels(), fontsize=fontsize_minor)

# %% [markdown]
# # test loss

# %%
loss_df = pd.read_csv(f'./results/ts2vec/test_loss_ts2vec.csv') # Generated by src.modeling.test_ts2vec.py script

fig, ax = plt.subplots(1, figsize=(5,5))

b = sns.lineplot(data=loss_df, x='Epoch', y='Loss', ax=ax)

# b.set(ylim=(0.2, 0.5))

b.set_xlabel(b.get_xlabel(), fontsize=fontsize)
b.set_ylabel(b.get_ylabel(), fontsize=fontsize)

b.set_xticklabels(b.get_xticklabels(), fontsize=fontsize_minor)
b.set_yticklabels(b.get_yticklabels(), fontsize=fontsize_minor)

b.set_title('TS2Vec train loss', fontsize=fontsize)

sns.despine(top=True, right=True)
# Out:
# /tmp/ipykernel_3663584/1658459749.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   b.set_xticklabels(b.get_xticklabels(), fontsize=fontsize_minor)
# /tmp/ipykernel_3663584/1658459749.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   b.set_yticklabels(b.get_yticklabels(), fontsize=fontsize_minor)

# %%
loss_df = pd.read_csv(f'./results/ts2vec/test_loss_ts2vec_k.csv') # Generated by src.modeling.test_ts2vec.py script

fig, ax = plt.subplots(1, figsize=(5,5))

b = sns.lineplot(data=loss_df, x='Epoch', y='Loss', ax=ax)

# b.set(ylim=(0.2, 0.5))

b.set_xlabel(b.get_xlabel(), fontsize=fontsize)
b.set_ylabel(b.get_ylabel(), fontsize=fontsize)

b.set_xticklabels(b.get_xticklabels(), fontsize=fontsize_minor)
b.set_yticklabels(b.get_yticklabels(), fontsize=fontsize_minor)

b.set_title('TS2Vec train loss', fontsize=fontsize)

sns.despine(top=True, right=True)
# Out:
# /tmp/ipykernel_3663584/2407747838.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   b.set_xticklabels(b.get_xticklabels(), fontsize=fontsize_minor)
# /tmp/ipykernel_3663584/2407747838.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   b.set_yticklabels(b.get_yticklabels(), fontsize=fontsize_minor)
