# %%
# verify if the environment (ts-classification-env) is correct and node is as expected (scotia or hermann)
import sys
print(sys.executable)

import socket
print(socket.gethostname())
# Out:
# /home/pborole/anaconda3/envs/timesfm_py311/bin/python3.11
# scotia03.inf.ed.ac.uk

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import seaborn as sns
from sklearn.metrics import (
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    precision_recall_curve
)

# %% [markdown]
# # TimesFM

# %%
ename = 'timesfm'
result_df = pd.read_csv(f'./results/predictions/final_test_predictions_tsclassifier_{ename}.csv')
y_true = result_df['y_true'].to_list()
y_pred = result_df['y_pred'].to_list()
y_probs = result_df['y_probs'].to_list()

confusion_matrix = sklearn.metrics.confusion_matrix(y_true, y_pred)
# confusion_matrix = confusion_matrix/np.sum(confusion_matrix)*100
sns.heatmap(confusion_matrix, annot=True, xticklabels=False, yticklabels=False, cbar=False, cmap="Blues",fmt='g')
plt.title(f'Confusion Matrix using {ename} embedder + MLP')
plt.xticks([0.5,1.5],['Control','Cip'],rotation=45)
plt.yticks([0.5,1.5],['Control','Cip'],rotation=45)


# Accurcy
accuracy = accuracy_score(y_pred=y_pred, y_true=y_true)
# AUROC
auroc = roc_auc_score(y_true, y_probs)
# AUPRC
precision, recall, _ = precision_recall_curve(y_true, y_probs)
auprc = auc(recall, precision)
# Precision
precision = precision_score(y_true, y_pred, zero_division=0)
# Recall
recall = recall_score(y_true, y_pred, zero_division=0)
# f1
f1 = f1_score(y_true, y_pred, zero_division=0)

print(
    f"accuracy: {accuracy} \n"
    f"precision: {precision}  \n"
    f"recall: {recall}  \n"
    f"f1: {f1}  \n"
    f"auroc: {auroc}  \n"
    f"auprc: {auprc} \n"
)
# Out:
# accuracy: 0.7777777777777778
# precision: 0.8095238095238095
# recall: 0.8439716312056738
# f1: 0.8263888888888888
# auroc: 0.814758527524485
# auprc: 0.8646623922757288

# %% [markdown]
# # MOMENT 1 BASE

# %%
ename = 'moment'
result_df = pd.read_csv(f'./results/predictions/final_test_predictions_tsclassifier_{ename}.csv')
y_true = result_df['y_true'].to_list()
y_pred = result_df['y_pred'].to_list()

confusion_matrix = sklearn.metrics.confusion_matrix(y_true, y_pred)
# confusion_matrix = confusion_matrix/np.sum(confusion_matrix)*100
sns.heatmap(confusion_matrix, annot=True, xticklabels=False, yticklabels=False, cbar=False, cmap="Blues",fmt='g')
plt.title(f'Confusion Matrix using {ename} embedder + MLP')
plt.xticks([0.5,1.5],['Control','Cip'],rotation=45)
plt.yticks([0.5,1.5],['Control','Cip'],rotation=45)

# Accurcy
accuracy = accuracy_score(y_pred=y_pred, y_true=y_true)
# AUROC
auroc = roc_auc_score(y_true, y_probs)
# AUPRC
precision, recall, _ = precision_recall_curve(y_true, y_probs)
auprc = auc(recall, precision)
# Precision
precision = precision_score(y_true, y_pred, zero_division=0)
# Recall
recall = recall_score(y_true, y_pred, zero_division=0)
# f1
f1 = f1_score(y_true, y_pred, zero_division=0)

print(
    f"accuracy: {accuracy} \n"
    f"precision: {precision}  \n"
    f"recall: {recall}  \n"
    f"f1: {f1}  \n"
    f"auroc: {auroc}  \n"
    f"auprc: {auprc} \n"
)
# Out:
# accuracy: 0.88
# precision: 0.8701298701298701
# recall: 0.950354609929078
# f1: 0.9084745762711864
# auroc: 0.814758527524485
# auprc: 0.8646623922757288
